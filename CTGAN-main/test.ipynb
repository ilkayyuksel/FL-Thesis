# %%
from ctgan import CTGAN
from ctgan import load_demo

real_data = load_demo()

# %%
real_data
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan = CTGAN(epochs=10)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(1000)

# %%
synthetic_data
# Out:
#      age          workclass  fnlwgt      education  education-num  \
# 0     27       Self-emp-inc   61330           11th              9
# 1     38          Local-gov   81365   Some-college             10
# 2     42   Self-emp-not-inc  189664      Bachelors             14
# 3     38                  ?  188337     Assoc-acdm              9
# 4     30          State-gov  224200      Preschool             13
# ..   ...                ...     ...            ...            ...
# 995   38          State-gov  225787   Some-college             13
# 996   21            Private  240370   Some-college             10
# 997   37            Private  285718   Some-college             10
# 998   20            Private  258026        HS-grad             10
# 999   58   Self-emp-not-inc  402348   Some-college             10
#
#              marital-status          occupation     relationship    race  \
# 0     Married-spouse-absent   Machine-op-inspct          Husband   White
# ...

# %%
import pandas as pd
real_data = pd.read_parquet("UNSW_NB15_training-set.parquet")

# %%
real_data = real_data.iloc[:len(real_data)//2]
real_data = real_data.iloc[:len(real_data)//2]

# %%
real_data
# Out:
#             dur proto   service state  spkts  dpkts  sbytes  dbytes  \
# 0      0.000011   udp         -   INT      2      0     496       0
# 1      0.000008   udp         -   INT      2      0    1762       0
# 2      0.000005   udp         -   INT      2      0    1068       0
# 3      0.000006   udp         -   INT      2      0     900       0
# 4      0.000010   udp         -   INT      2      0    2126       0
# ...         ...   ...       ...   ...    ...    ...     ...     ...
# 10286  0.975429   tcp         -   FIN     12     10    3088     441
# 10287  0.322438   tcp  ftp-data   FIN      8      8     364     950
# 10288  2.026296   tcp      smtp   FIN     26     20    9101    1766
# 10289  0.215777   tcp      http   FIN     10      8     788    1648
# 10290  0.702526   tcp      smtp   FIN     24     20    5637    1770
#
#                 rate         sload  ...  trans_depth  response_body_len  \
# 0       90909.093750  1.803636e+08  ...            0                  0
# ...

# %%
real_data = real_data.drop(['rate', 'sload', 'dload', 'sloss', 'dloss', 'label'], axis=1)
real_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10291 entries, 0 to 10290
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   dur                10291 non-null  float32
#  1   spkts              10291 non-null  int16
#  2   dpkts              10291 non-null  int16
#  3   sbytes             10291 non-null  int32
#  4   dbytes             10291 non-null  int32
#  5   sinpkt             10291 non-null  float32
#  6   dinpkt             10291 non-null  float32
#  7   sjit               10291 non-null  float32
#  8   djit               10291 non-null  float32
#  9   swin               10291 non-null  int16
#  10  stcpb              10291 non-null  int64
#  11  dtcpb              10291 non-null  int64
#  12  dwin               10291 non-null  int16
#  13  tcprtt             10291 non-null  float32
#  14  synack             10291 non-null  float32
#  15  ackdat             10291 non-null  float32
# ...

# %%
# Names of the columns that are discrete
discrete_columns = ['dur', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin', 'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth', 'response_body_len', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'is_sm_ips_ports']

ctgan = CTGAN(epochs=5)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(10)
# Out:
# KeyboardInterrupt
