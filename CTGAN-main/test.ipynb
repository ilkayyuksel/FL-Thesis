# %%
from ctgan import CTGAN
from ctgan import load_demo

real_data = load_demo()

# Names of the columns that are discrete
discrete_columns = [
    'workclass',
    'education',
    'marital-status',
    'occupation',
    'relationship',
    'race',
    'sex',
    'native-country',
    'income'
]

ctgan = CTGAN(epochs=10)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(1000)

# %%
synthetic_data
# Out:
#      age          workclass  fnlwgt      education  education-num  \
# 0     38            Private  192025   Some-college             12
# 1     72          Local-gov  225765      Bachelors             11
# 2     51            Private  450062        Masters              4
# 3     35          Local-gov  182909   Some-college             12
# 4     61                  ?  295886        HS-grad              9
# ..   ...                ...     ...            ...            ...
# 995   36            Private  215502        Masters             12
# 996   38            Private   60902        Masters             14
# 997   29            Private  159158        HS-grad              0
# 998   36            Private  183513           11th             10
# 999   38   Self-emp-not-inc  216270      Bachelors              9
#
#           marital-status          occupation     relationship    race  \
# 0          Never-married        Adm-clerical    Not-in-family   White
# ...

# %%
from ctgan import CTGAN
from ctgan import load_demo
import pandas as pd
real_data = pd.read_parquet("UNSW_NB15_training-set.parquet")
metadata=["service","label", "attack_cat", "proto", "state"]
real_data.drop(columns=metadata,inplace=True)
# Names of the columns that are discrete
discrete_columns = ['dur',
 'spkts',
 'dpkts',
 'sbytes',
 'dbytes',
 'rate',
 'sload',
 'dload',
 'sloss',
 'dloss',
 'sinpkt',
 'dinpkt',
 'sjit',
 'djit',
 'swin',
 'stcpb',
 'dtcpb',
 'dwin',
 'tcprtt',
 'synack',
 'ackdat',
 'smean',
 'dmean',
 'trans_depth',
 'response_body_len',
 'ct_src_dport_ltm',
 'ct_dst_sport_ltm',
 'is_ftp_login',
 'ct_ftp_cmd',
 'ct_flw_http_mthd',
 'is_sm_ips_ports']

ctgan = CTGAN(epochs=5)
ctgan.fit(real_data, discrete_columns)

# Create synthetic data
synthetic_data = ctgan.sample(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 41
#       8 discrete_columns = ['dur',
#       9  'spkts',
#      10  'dpkts',
#    (...)
#      37  'ct_flw_http_mthd',
#      38  'is_sm_ips_ports']
#      40 ctgan = CTGAN(epochs=5)
# ---> 41 ctgan.fit(real_data, discrete_columns)
#      43 # Create synthetic data
#      44 synthetic_data = ctgan.sample(10)
#
# File d:\1ste Master\MasterThesis\CTGAN-main\CTGAN-main\ctgan\synthesizers\base.py:50, in random_state.<locals>.wrapper(self, *args, **kwargs)
#      48 def wrapper(self, *args, **kwargs):
#      49     if self.random_states is None:
# ---> 50         return function(self, *args, **kwargs)
#      52     else:
#      53         with set_random_states(self.random_states, self.set_random_state):
#
# ...
